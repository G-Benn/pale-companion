# %% [markdown]
# ## What does this do?
# This is a one-time processing of the other works by Wildbow in preparation of using them as a fine-tuning (and future) search mechanism for the model / lookup system.
#
# Note: While there will be some basic metadata here, depending on the difficulty / manual effort required to get it into the same shape as Pale it may not be done in the current form. Pale had a spreadsheet with additional information (PoV, wordcount, etc) that isn't available here.

# %%
from bs4 import BeautifulSoup
import re
import pandas as pd
import os
import pickle

# %% [markdown]
# ### Worm

# %%
dir_prefix = '../data/worm/'
all_files = sorted([f for f in os.listdir(dir_prefix) if os.path.isfile(os.path.join(dir_prefix,f)) and f.endswith('.html')])

# %%
tmp = all_files[92]
with open(dir_prefix + tmp) as fp:
        soup = BeautifulSoup(fp,features='xml')
print(soup.title.string)
full_title = soup.title.string
if 'interlude' in full_title.lower(): 
        # Different structure
        arc_name = None
        arc_number = None
        chapter_number = 'i' + re.search(r'\d+',full_title).group()
        is_interlude = True
else:
        arc_name = re.split(r' \d',full_title)[0]
        arc_num = re.search(r'\d+\.\d+', full_title).group()
        arc_number, chapter_number = arc_num.split('.')[0], arc_num.split('.')[1]
        is_interlude = False

print(arc_name, arc_number, chapter_number)

text = soup.body
text.h1.decompose()
clean_text = text.getText().replace(u'\xa0', ' ')
        # splits[0] + re.split(r' ',splits[1])[0]
# Out:
# Interlude 16 (Donation Bonus #3)
# None None i16

# %%
parsed_files = []
for fname in all_files:
    file_number = int(re.search(r'\d+',fname).group())
    # print(file_number)
    with open(dir_prefix + fname) as fp:
        soup = BeautifulSoup(fp,features='xml')

    # print(soup.title.string)
    full_title = soup.title.string
    if 'interlude' in full_title.lower(): 
            # Different structure
            arc_name = None
            arc_number = None
            if ' End' in full_title:
                chapter_number = 'end'
            else:
                chapter_number = 'i' + re.search(r'\d+',full_title).group()
            chapter_type = 'Interlude'
    else:
            arc_name = re.split(r' \d',full_title)[0]
            if 'Teneral' in arc_name:
                arc_num = re.search(r'\w+\.\d+', full_title).group()
            else:
                arc_num = re.search(r'\d+\.\d+', full_title).group()
            arc_number, chapter_number = arc_num.split('.')[0], arc_num.split('.')[1]
            chapter_type = 'Taylor'

    # print(arc_name, arc_number, chapter_number)

    text = soup.body
    text.h1.decompose()
    clean_text = text.getText().replace(u'\xa0', ' ')
    # TODO Format this so it matches the text / metadata format Haystack expects
    d = {
        # Some of this information is going to removed in favor of the spreadsheet versions
        'arc_title': arc_name,
        'arc_number': arc_number,
        'chapter_number': chapter_number,
        'chapter_type': chapter_type,
        'text': clean_text,
        'file_number':file_number
    }
    parsed_files.append(d)
df = pd.DataFrame(parsed_files)
df = df.drop_duplicates(subset=['arc_number','chapter_number'])

# %%
df = df.sort_values('file_number',ascending=True)
df['absolute_file_number'] = range(1,len(df)+1) # 1-indexed
df[['arc_title','arc_number']] = df[['arc_title','arc_number']].fillna(method='ffill')
df['chapter'] = df['arc_number'].astype(str) + "." + df['chapter_number'].astype(str)
df = df.sort_values(by='absolute_file_number', ascending=True)
df = df.fillna('')
df.sample(n=5)
# Out:
#        arc_title arc_number chapter_number chapter_type  \
# 63        Colony         15              1       Taylor
# 219        Speck         30              4       Taylor
# 110  Insinuation          2              9       Taylor
# 45         Snare         13              8       Taylor
# 247         Hive          5              1       Taylor
#
#                                                   text  file_number  \
# 63   \nBentley lunged in my direction, and I could ...          157
# 219  \nI didn’t break eye contact with Dragon.  My ...          299
# 110  \nAs Brian and I returned to the loft, I felt ...           20
# 45   \n“I was a lot more comfortable with the risky...          140
# 247  \nThe place was nondescript.  A hole in the wa...           48
#
#      absolute_file_number chapter
# 63                    140    15.1
# 219                   263    30.4
# 110                    16     2.9
# 45                    125    13.8
# 247                    43     5.1

# %%
raw_dict = df.to_dict(orient='index')
worm_construct_list = [
    {'content':i['text'], 'meta': {
        'arc_title': i['arc_title'],
        'series_chapter_number': i['absolute_file_number'],
        'arc_number': i['arc_number'],
        'pov': i['chapter_type'],
        'title': i['arc_title'] + ' - ' + i['chapter'],
        'chapter': i['chapter'].lower() # We'll use it later as a join key
    }}
    for idx, i in raw_dict.items()
    ]

# %%
with open('../data/worm_fmt_list.pkl','wb') as f:
    pickle.dump(worm_construct_list,f)

# %% [markdown]
# ## Ward

# %%
dir_prefix = '../data/ward/OEBPS/chapters/'
all_files = sorted([f for f in os.listdir(dir_prefix) if os.path.isfile(os.path.join(dir_prefix,f)) and f.endswith('.xhtml')])

# %%
tmp = all_files[99]
file_number = int(re.search(r'\d+',tmp).group())
# print(file_number)
with open(dir_prefix + tmp) as fp:
        soup = BeautifulSoup(fp,features='xml')
print(soup.title.string)
full_title = soup.title.string
if 'interlude' in full_title.lower(): 
        # Different structure
        arc_name = re.split(r' Interlude',full_title)[0]
        arc_num = re.search(r'\d+\.\w+', full_title).group()
        arc_number, chapter_number = arc_num.split('.')[0], arc_num.split('.')[1]
        is_interlude = True
else:
        arc_name = re.split(r' \d',full_title)[0]
        arc_num = re.search(r'\d+\.\d+', full_title).group()
        arc_number, chapter_number = arc_num.split('.')[0], arc_num.split('.')[1]
        is_interlude = False

print(arc_name, arc_number, chapter_number)

text = soup.body
text.h1.decompose()
clean_text = text.getText().replace(u'\xa0', ' ')
        # splits[0] + re.split(r' ',splits[1])[0]
# Out:
# Gleaming Interlude 9.x
# Gleaming 9 x

# %%
parsed_files = []
for fname in all_files:
    file_number = int(re.search(r'\d+',fname).group())
    # print(file_number)
    with open(dir_prefix + fname) as fp:
        soup = BeautifulSoup(fp,features='xml')

    # print(soup.title.string)
    # print(soup.title.string)
    full_title = soup.title.string
    if 'interlude' in full_title.lower() or re.search(r'\d+\.\D+', full_title.lower()): 
            # Different structure
            arc_name = re.split(r' Interlude',full_title)[0]
            if '.' in full_title:
                arc_num = re.search(r'\d+\.\w+', full_title).group()
                arc_number, chapter_number = arc_num.split('.')[0], arc_num.split('.')[1]
            else:
                arc_number = None
                chapter_number = 'i' + re.search(r'\d+',full_title).group()
            chapter_type = 'Interlude'
    else:
            arc_name = re.split(r' \d',full_title)[0]
            if 'Eclipse' in arc_name:
                arc_num = re.search(r'\w+\.\d+', full_title).group()
            
            else:
                arc_num = re.search(r'\d+\.\d+', full_title).group()
            arc_number, chapter_number = arc_num.split('.')[0], arc_num.split('.')[1]
            chapter_type = 'Victoria'

    # print(arc_name, arc_number, chapter_number)

    text = soup.body
    text.h1.decompose()
    clean_text = text.getText().replace(u'\xa0', ' ')
    # TODO Format this so it matches the text / metadata format Haystack expects
    d = {
        # Some of this information is going to removed in favor of the spreadsheet versions
        'arc_title': arc_name,
        'arc_number': arc_number,
        'chapter_number': chapter_number,
        'chapter_type': chapter_type,
        'text': clean_text,
        'file_number':file_number
    }
    parsed_files.append(d)
df = pd.DataFrame(parsed_files)
df = df.drop_duplicates(subset=['arc_number','chapter_number'])

# %%
df = df.sort_values('file_number',ascending=True)
df['absolute_file_number'] = range(1,len(df)+1) # 1-indexed
df[['arc_title','arc_number']] = df[['arc_title','arc_number']].fillna(method='ffill')
df['chapter'] = df['arc_number'].astype(str) + "." + df['chapter_number'].astype(str)
df = df.sort_values(by='absolute_file_number', ascending=True)
df = df.fillna('')
df.sample(n=5)
# Out:
#      arc_title arc_number chapter_number chapter_type  \
# 41      Shadow          5              7     Victoria
# 132   Blinding         11              5     Victoria
# 172   Breaking         14              3     Victoria
# 143    Heavens         12              1     Victoria
# 228  Radiation         18              7     Victoria
#
#                                                   text  file_number  \
# 41   \n\n\nIt was an overcast day.  Our nights were...           41
# 132  \n\n\nThe ‘joints’ of the spider’s limbs were ...          132
# 172  \n\n\nThere were no big television cameras to ...          172
# 143  \n\n\nThe red and blue lights from the police ...          143
# 228  \n\n\nThe five-pound phone I carried blared.  ...          228
#
#      absolute_file_number chapter
# 41                     40     5.7
# 132                   131    11.5
# 172                   171    14.3
# 143                   142    12.1
# 228                   227    18.7

# %%
raw_dict = df.to_dict(orient='index')
ward_construct_list = [
    {'content':i['text'], 'meta': {
        'arc_title': i['arc_title'],
        'series_chapter_number': i['absolute_file_number'],
        'arc_number': i['arc_number'],
        'pov': i['chapter_type'],
        'title': i['arc_title'] + ' - ' + i['chapter'],
        'chapter': i['chapter'].lower() # We'll use it later as a join key
    }}
    for idx, i in raw_dict.items()
    ]

# %%
with open('../data/ward_fmt_list.pkl','wb') as f:
    pickle.dump(ward_construct_list,f)

# %% [markdown]
# ### Pact

# %%
dir_prefix = '../data/pact/'
all_files = sorted([f for f in os.listdir(dir_prefix) if os.path.isfile(os.path.join(dir_prefix,f)) and f.endswith('.html')])

# %%
parsed_files = []
for fname in all_files:
        file_number = int(re.search(r'\d+',fname).group())
        # print(file_number)
        with open(dir_prefix + fname) as fp:
                soup = BeautifulSoup(fp,features='xml')
        # print(soup.title.string)
        full_title = soup.title.string
        if 'gathered' in full_title.lower() or 'pages' in full_title.lower(): 
                # Different structure
                print("Gathered Pages")
                arc_name = None
                arc_number = None
                chapter_number = 'i' + str(int(re.search(r'\d+',full_title).group()))
                chapter_type = 'Gathered Pages'
        elif 'histories' in full_title.lower():
                arc_name = None
                if 'Arc' in full_title:
                        arc_number = int(re.search(r'Arc \d+',full_title).group().split(' ')[1])
                else:
                        arc_number = int(re.search(r'\d+',full_title).group())
                chapter_number = 'i' + str(int(re.search(r'\d+',full_title).group()))
                chapter_type = 'Histories'
        elif 'epilogue' in full_title.lower():
                arc_name = 'Epilogue'
                arc_number = 'End'
                chapter = 'End'
                chapteR_type = 'Epilogue'
        else:
                # print(full_title)
                arc_name = re.split(r' \d',full_title)[0]
                arc_num = re.search(r'\d+\.\d+', full_title).group()
                arc_number, chapter_number = arc_num.split('.')[0], arc_num.split('.')[1]
                chapter_type = 'Chapter'

        # print(arc_name, arc_number, chapter_number)

        text = soup.body
        text.h1.decompose()
        clean_text = text.getText().replace(u'\xa0', ' ')
        d = {
        'arc_title': arc_name,
        'arc_number': arc_number,
        'chapter_number': chapter_number,
        'chapter_type': chapter_type,
        'text': clean_text,
        'file_number':file_number
    }
        parsed_files.append(d)
df = pd.DataFrame(parsed_files)
df = df.drop_duplicates(subset=['arc_number','chapter_number'])
# Out:
# Gathered Pages
# Gathered Pages
# Gathered Pages
# Gathered Pages
# Gathered Pages

# %%
df = df.sort_values('file_number',ascending=True)
df['absolute_file_number'] = range(1,len(df)+1) # 1-indexed
df[['arc_title','arc_number']] = df[['arc_title','arc_number']].fillna(method='ffill')
df['chapter'] = df['arc_number'].astype(str) + "." + df['chapter_number'].astype(str)
df = df.sort_values(by='absolute_file_number', ascending=True)
df = df.fillna('')
df.sample(n=5)
# Out:
#       arc_title arc_number chapter_number chapter_type  \
# 131       Bonds          1              4      Chapter
# 39     Sine Die         14            i14    Histories
# 42   Possession         15              3      Chapter
# 119        Void          7             10      Chapter
# 133        Null          9              3      Chapter
#
#                                                   text  file_number  \
# 131  \nI finished toweling myself dry and wrapped t...            8
# 39   \nThe wind blew, pulling dry bits of vegetatio...          135
# 42   \nThe top of the pillar was bright compared to...          138
# 119  \nThe sudden shifts in weather had made for so...           69
# 133  \nI clenched my fists, but neither was in part...           81
#
#      absolute_file_number chapter
# 131                     4     1.4
# 39                    131  14.i14
# 42                    134    15.3
# 119                    65    7.10
# 133                    77     9.3

# %%
raw_dict = df.to_dict(orient='index')
pact_construct_list = [
    {'content':i['text'], 'meta': {
        'arc_title': i['arc_title'],
        'series_chapter_number': i['absolute_file_number'],
        'arc_number': i['arc_number'],
        'pov': i['chapter_type'],
        'title': i['arc_title'] + ' - ' + i['chapter'],
        'chapter': i['chapter'].lower() # We'll use it later as a join key
    }}
    for idx, i in raw_dict.items()
    ]

# %%
with open('../data/pact_fmt_list.pkl','wb') as f:
    pickle.dump(pact_construct_list,f)

# %% [markdown]
# ## Glow-worm

# %%
dir_prefix = '../data/glow-worm/'
all_files = sorted([f for f in os.listdir(dir_prefix) if os.path.isfile(os.path.join(dir_prefix,f)) and f.endswith('.html')])

# %%
parsed_files = []
for fname in all_files:
        file_number = int(re.search(r'\d+',fname).group())
        # print(file_number)
        with open(dir_prefix + fname) as fp:
                soup = BeautifulSoup(fp,features='xml')
        print(soup.title.string)
        full_title = soup.title.string
        arc_name = full_title.split('.')[0]
        arc_number = full_title.split('.')[0]
        chapter_number = full_title.split('.')[1]
        chapter_type = 'Chapter'

        print(arc_name, arc_number, chapter_number)

        text = soup.body
        text.h1.decompose()
        clean_text = text.getText().replace(u'\xa0', ' ')
        d = {
        'arc_title': arc_name,
        'arc_number': arc_number,
        'chapter_number': chapter_number,
        'chapter_type': chapter_type,
        'text': clean_text,
        'file_number':file_number
        }
        parsed_files.append(d)
df = pd.DataFrame(parsed_files)
df = df.drop_duplicates(subset=['arc_number','chapter_number'])
# Out:
# P.6
# P P 6
# P.7
# P P 7
# P.8
# P P 8
# P.9
# P P 9
# P.1
# P P 1
# P.2
# P P 2
# P.3
# P P 3
# P.4
# P P 4
# P.5
# P P 5

# %%
df = df.sort_values('file_number',ascending=True)
df['absolute_file_number'] = range(1,len(df)+1) # 1-indexed
df[['arc_title','arc_number']] = df[['arc_title','arc_number']].fillna(method='ffill')
df['chapter'] = df['arc_number'].astype(str) + "." + df['chapter_number'].astype(str)
df = df.sort_values(by='absolute_file_number', ascending=True)
df = df.fillna('')
df.sample(n=5)
# Out:
#   arc_title arc_number chapter_number chapter_type  \
# 8         P          P              5      Chapter
# 7         P          P              4      Chapter
# 3         P          P              9      Chapter
# 5         P          P              2      Chapter
# 2         P          P              8      Chapter
#
#                                                 text  file_number  \
# 8  \nSubject: Your Nilles University Application\...            9
# 7  \nWelcome to the Parahumans Online message boa...            8
# 3  \n♦  You have four unread private messages fro...           13
# 5  \nWelcome to the Parahumans Online message boa...            6
# 2  \nSubject: PHO Technical Assistance\nAugust 24...           12
#
#    absolute_file_number chapter
# 8                     5     P.5
# 7                     4     P.4
# 3                     9     P.9
# 5                     2     P.2
# 2                     8     P.8

# %%
raw_dict = df.to_dict(orient='index')
glowworm_construct_list = [
    {'content':i['text'], 'meta': {
        'arc_title': i['arc_title'],
        'series_chapter_number': i['absolute_file_number'],
        'arc_number': i['arc_number'],
        'pov': i['chapter_type'],
        'title': i['arc_title'] + ' - ' + i['chapter'],
        'chapter': i['chapter'].lower() # We'll use it later as a join key
    }}
    for idx, i in raw_dict.items()
    ]

# %%
with open('../data/glowworm_fmt_list.pkl','wb') as f:
    pickle.dump(glowworm_construct_list,f)

# %% [markdown]
# ## Twig

# %%
dir_prefix = '../data/twig/'
all_files = sorted([f for f in os.listdir(dir_prefix) if os.path.isfile(os.path.join(dir_prefix,f)) and f.endswith('.html')])

# %%
parsed_files = []
for fname in all_files:
    file_number = int(re.search(r'\d+',fname).group())
    # print(file_number)
    with open(dir_prefix + fname) as fp:
        soup = BeautifulSoup(fp,features='xml')

    print(soup.title.string)
    full_title = soup.title.string
    if 'enemy' in full_title.lower():
        arc_name = None
        arc_number = int(re.search(r'Arc \d+', full_title).group().split(' ')[1])
        chapter_number = 'i' + str(arc_number)
        if '–' in full_title:
            chapter_type = re.sub('[\W_]', '',full_title.split('–')[1])
        else:
            chapter_type = 'Enemy'
    elif 'lamb' in full_title.lower() and 'slaughter' not in full_title.lower():
        if 'black sheep' in full_title.lower():
            arc_name = re.split(r' \d',full_title)[0]
            arc_name = re.sub('–', '',arc_name).strip()
            arc_num = re.search(r'\d+\.\d+', full_title).group()
            arc_number, chapter_number = arc_num.split('.')[0], arc_num.split('.')[1]
            chapter_type = 'Lamb'
        else:
            arc_name = None
            arc_number = int(re.search(r'Arc \d+', full_title).group().split(' ')[1])
            chapter_number = 'i' + str(arc_number)
            chapter_type = 'Lamb'
    elif 'e.' in full_title.lower():
        arc_name = full_title.split('–')[0]
        arc_number = 'e'
        chapter_number = int(re.search(r'\.\d+',full_title).group().split('.')[1])
        chapter_type = 'Epilogue'
    else:
        arc_name = re.split(r' \d',full_title)[0]
        arc_name = re.sub('–', '',arc_name).strip()
        arc_num = re.search(r'\d+\.\d+', full_title).group()
        arc_number, chapter_number = arc_num.split('.')[0], arc_num.split('.')[1]
        chapter_type = 'Chapter'

    d = {
        'arc_title': arc_name,
        'arc_number': arc_number,
        'chapter_number': chapter_number,
        'chapter_type': chapter_type,
        'text': clean_text,
        'file_number':file_number
        }
    parsed_files.append(d)
df = pd.DataFrame(parsed_files)
df = df.drop_duplicates(subset=['arc_number','chapter_number'])
# Out:
# Taking Root 1.6
# Enemy (Arc 7 – Boys)
# Enemy (Arc 7 – Girls)
# Bleeding Edge – 8.1
# Bleeding Edge – 8.2
# Bleeding Edge – 8.3
# Bleeding Edge – 8.4
# Bleeding Edge – 8.5
# Bleeding Edge – 8.6
# Bleeding Edge – 8.7
# Bleeding Edge – 8.8
# Taking Root 1.7
# Bleeding Edge – 8.9
# Bleeding Edge – 8.10
# Bleeding Edge – 8.11
# Bleeding Edge – 8.12
# Bleeding Edge – 8.13
# Bleeding Edge – 8.14
# Bleeding Edge – 8.15
# Bleeding Edge – 8.16
# Enemy (Arc 8)
# Counting Sheep – 9.1
# Taking Root 1.8
# Counting Sheep – 9.2
# Counting Sheep – 9.3
# Counting Sheep – 9.4
# Counting Sheep – 9.5
# Counting Sheep – 9.6
# Counting Sheep – 9.7
# Counting Sheep – 9.8
# Counting Sheep – 9.9
# Counting Sheep – 9.10
# Counting Sheep – 9.11
# Taking Root 1.9
# Counting Sheep – 9.12
# Counting Sheep – 9.13
# Counting Sheep – 9.14
# Counting Sheep – 9.15
# Counting Sheep – 9.16
# Counting Sheep – 9.17
# Counting Sheep – 9.18
# Enemy (Arc 9)
# In Sheep’s Clothing – 10.1
# In Sheep’s Clothing – 10.2
# Taking Root 1.10
# In Sheep’s Clothing – 10.3
# In Sheep’s Clothing – 10.4
# In Sheep’s Clothing – 10.5
# In Sheep’s Clothing – 10.6
# In Sheep’s Clothing – 10.7
# In Sheep’s Clothing – 10.8
# In Sheep’s Clothing – 10.9
# In Sheep’s Clothing – 10.10
# In Sheep’s Clothing – 10.11
# In Sheep’s Clothing – 10.12
# Taking Root 1.11
# In Sheep’s Clothing – 10.13
# In Sheep’s Clothing – 10.14
# In Sheep’s Clothing – 10.15
# In Sheep’s Clothing – 10.16
# In Sheep’s Clothing – 10.17
# In Sheep’s Clothing – 10.18
# In Sheep’s Clothing – 10.19
# In Sheep’s Clothing – 10.20
# Lamb – Arc 10
# Cut to the Quick – 11.1
# Taking Root 1.12
# Cut to the Quick – 11.2
# Cut to the Quick – 11.3
# Cut to the Quick – 11.4
# Cut to the Quick – 11.5
# Cut to the Quick – 11.6
# Cut to the Quick – 11.7
# Cut to the Quick – 11.8
# Cut to the Quick – 11.9
# Cut to the Quick – 11.10
# Cut to the Quick – 11.11
# Enemy (Arc 1)
# Cut to the Quick – 11.12
# Cut to the Quick – 11.13
# Cut to the Quick – 11.14
# Cut to the Quick – 11.15
# Lamb (Arc 11)
# Dyed in the Wool – 12.1
# Dyed in the Wool – 12.2
# Dyed in the Wool – 12.3
# Dyed in the Wool – 12.4
# Dyed in the Wool – 12.5
# Cat out of the Bag 2.1
# Dyed in the Wool – 12.6
# Dyed in the Wool – 12.7
# Dyed in the Wool – 12.8
# Dyed in the Wool – 12.9
# Dyed in the Wool – 12.10
# Dyed in the Wool – 12.11
# Dyed in the Wool – 12.12
# Black Sheep – 13.1 (Lamb)
# Black Sheep – 13.2 (Lamb)
# Black Sheep – 13.3 (Lamb)
# Cat out of the Bag 2.2
# Black Sheep – 13.4 (Lamb)
# Black Sheep – 13.5 (Lamb)
# Black Sheep – 13.6 (Lamb)
# Black Sheep – 13.7
# Black Sheep – 13.8 (Lamb)
# Black Sheep – 13.9 (Lamb)
# Black Sheep – 13.10 (Lamb)
# Black Sheep – 13.11
# Thicker than Water – 14.1
# Thicker than Water – 14.2
# Cat out of the Bag 2.3
# Thicker than Water – 14.3
# Thicker than Water – 14.4
# Thicker than Water – 14.5
# Thicker than Water – 14.6
# Thicker than Water – 14.7
# Thicker than Water – 14.8
# Thicker than Water – 14.9
# Thicker than Water – 14.10
# Thicker than Water – 14.11
# Thicker than Water – 14.12
# Cat out of the Bag 2.4
# Thicker than Water – 14.13
# Thicker than Water – 14.14
# Thicker than Water – 14.15
# Thicker than Water – 14.16
# Thicker than Water – 14.17
# Thicker than Water – 14.18
# Lamb (Arc 14)
# Bitter Pill – 15.1
# Bitter Pill – 15.2
# Bitter Pill – 15.3
# Cat out of the Bag 2.5
# Bitter Pill – 15.4
# Bitter Pill – 15.5
# Bitter Pill – 15.6
# Bitter Pill – 15.7
# Bitter Pill – 15.8
# Bitter Pill – 15.9
# Bitter Pill – 15.10
# Bitter Pill – 15.11
# Bitter Pill – 15.12
# Bitter Pill – 15.13
# Cat out of the Bag 2.6
# Bitter Pill – 15.14
# Bitter Pill – 15.15
# Bitter Pill – 15.16
# Lamb (Arc 15)
# Head over Heels – 16.1
# Head over Heels – 16.2
# Head over Heels – 16.3
# Head over Heels – 16.4
# Head over Heels – 16.5
# Head over Heels – 16.6
# Cat out of the Bag 2.7
# Head over Heels – 16.7
# Head over Heels – 16.8
# Head over Heels – 16.9
# Head over Heels – 16.10
# Head over Heels – 16.11
# Head over Heels – 16.12
# Head over Heels – 16.13
# Lamb (Arc 16)
# Gut Feeling – 17.1
# Gut Feeling – 17.2
# Cat out of the Bag 2.8
# Gut Feeling – 17.3
# Gut Feeling – 17.4
# Gut Feeling – 17.5
# Gut Feeling – 17.6
# Gut Feeling – 17.7
# Gut Feeling – 17.8
# Gut Feeling – 17.9
# Gut Feeling – 17.10
# Gut Feeling – 17.11
# Gut Feeling – 17.12
# Cat out of the Bag 2.9
# Gut Feeling – 17.13
# Gut Feeling – 17.14
# Gut Feeling – 17.15
# Gut Feeling – 17.16
# Gut Feeling – 17.17
# Gut Feeling – 17.18
# Lamb (Arc 17)
# Dog Eat Dog – 18.1
# Dog Eat Dog – 18.2
# Dog Eat Dog – 18.3
# Cat out of the Bag 2.10
# Dog Eat Dog – 18.4
# Dog Eat Dog – 18.5
# Dog Eat Dog – 18.6
# Dog Eat Dog – 18.7
# Enemy I (Arc 18)
# Dog Eat Dog – 18.8
# Lamb I (Arc 18)
# Dog Eat Dog – 18.9
# Enemy II (Arc 18)
# Lamb II (Arc 18)
# Cat out of the Bag 2.11
# Dog Eat Dog – 18.10
# Lamb III (Arc 18)
# Enemy III (Arc 18)
# Enemy IV (Arc 18)
# Enemy V (Arc 18)
# Root and Branch – 19.1
# Root and Branch – 19.2
# Root and Branch – 19.3
# Root and Branch – 19.4
# Root and Branch – 19.5
# Enemy (Arc 2)
# Root and Branch – 19.6
# Root and Branch – 19.7
# Root and Branch – 19.8
# Root and Branch – 19.9
# Root and Branch – 19.10
# Root and Branch – 19.11
# Root and Branch – 19.12
# Root and Branch – 19.13
# Root and Branch – 19.14
# Root and Branch – 19.15
# Lips Sealed 3.1
# Enemy (Arc 19)
# Crown of Thorns – 20.1
# Crown of Thorns – 20.2
# Crown of Thorns – 20.3
# Crown of Thorns – 20.4
# Enemy (Arc 20)
# Crown of Thorns – 20.5
# Crown of Thorns – 20.6
# Crown of Thorns – 20.7
# Crown of Thorns – 20.8
# Lips Sealed 3.2
# Crown of Thorns – 20.9
# Crown of Thorns – 20.10
# Crown of Thorns – 20.11
# Crown of Thorns – 20.12
# Crown of Thorns – 20.13
# Crown of Thorns – 20.14
# Crown of Thorns – 20.15
# Crown of Thorns – 20.16
# Crown of Thorns – 20.17
# Crown of Thorns – 20.18
# Lips Sealed 3.3
# Crown of Thorns – 20.19
# Crown of Thorns – 20.20
# Forest for the Trees – e.1
# Forest for the Trees – e.2
# Forest for the Trees – e.3
# Forest for the Trees – e.4
# Lips Sealed 3.4
# Lips Sealed 3.5
# Lips Sealed 3.6
# Lips Sealed 3.7
# Lips Sealed 3.8
# Lips Sealed 3.9
# Lips Sealed 3.10
# Enemy (Arc 3)
# Stitch in Time – 4.1
# Stitch in Time – 4.2
# Stitch in Time – 4.3
# Stitch in Time – 4.4
# Stitch in Time – 4.5
# Stitch in Time – 4.6
# Stitch in Time – 4.7
# Stitch in Time – 4.8
# Stitch in Time – 4.9
# Taking Root 1.1
# Stitch in Time – 4.10
# Stitch in Time – 4.11
# Stitch in Time – 4.12
# Enemy (Arc 4)
# Esprit de Corpse – 5.1
# Esprit de Corpse – 5.2
# Esprit de Corpse – 5.3
# Esprit de Corpse – 5.4
# Esprit de Corpse – 5.5
# Esprit de Corpse – 5.6
# Taking Root 1.2
# Esprit de Corpse – 5.7
# Esprit de Corpse – 5.8
# Esprit de Corpse – 5.9
# Esprit de Corpse – 5.10
# Esprit de Corpse – 5.11
# Esprit de Corpse – 5.12
# Esprit de Corpse – 5.13
# Esprit de Corpse – 5.14
# Esprit de Corpse – 5.15
# Enemy (Arc 5)
# Taking Root 1.3
# Lamb to the Slaughter – 6.1
# Lamb to the Slaughter – 6.2
# Lamb to the Slaughter – 6.3
# Lamb to the Slaughter – 6.4
# Lamb to the Slaughter – 6.5
# Lamb to the Slaughter – 6.6
# Lamb to the Slaughter – 6.7
# Lamb to the Slaughter – 6.8
# Lamb to the Slaughter – 6.9
# Lamb to the Slaughter – 6.10
# Taking Root 1.4
# Lamb to the Slaughter – 6.11
# Lamb to the Slaughter – 6.12
# Lamb to the Slaughter – 6.13
# Enemy (Arc 6)
# Tooth and Nail – 7.1
# Tooth and Nail – 7.2
# Tooth and Nail – 7.3
# Tooth and Nail – 7.4
# Tooth and Nail – 7.5
# Tooth and Nail – 7.6
# Taking Root 1.5
# Tooth and Nail – 7.7
# Tooth and Nail – 7.8
# Tooth and Nail – 7.9
# Tooth and Nail – 7.10
# Tooth and Nail – 7.11
# Tooth and Nail – 7.12
# Tooth and Nail – 7.13
# Tooth and Nail – 7.14
# Tooth and Nail – 7.15
# Tooth and Nail – 7.16

# %%
df = df.sort_values('file_number',ascending=True)
df['absolute_file_number'] = range(1,len(df)+1) # 1-indexed
df[['arc_title','arc_number']] = df[['arc_title','arc_number']].fillna(method='ffill')
df['chapter'] = df['arc_number'].astype(str) + "." + df['chapter_number'].astype(str)
df = df.sort_values(by='absolute_file_number', ascending=True)
df = df.fillna('')
df.sample(n=5)
# Out:
#                arc_title arc_number chapter_number chapter_type  \
# 13         Bleeding Edge          8             10      Chapter
# 276     Esprit de Corpse          5              6      Chapter
# 220          Lips Sealed          3              1      Chapter
# 57   In Sheep’s Clothing         10             14      Chapter
# 138          Bitter Pill         15              9      Chapter
#
#                                                   text  file_number  \
# 13   \nSubject: Your Nilles University Application\...          111
# 276  \nSubject: Your Nilles University Application\...           59
# 220  \nSubject: Your Nilles University Application\...           30
# 57   \nSubject: Your Nilles University Application\...          151
# 138  \nSubject: Your Nilles University Application\...          225
#
#      absolute_file_number chapter
# 13                    106    8.10
# 276                    55     5.6
# 220                    26     3.1
# 57                    146   10.14
# 138                   220    15.9

# %%
raw_dict = df.to_dict(orient='index')
twig_construct_list = [
    {'content':i['text'], 'meta': {
        'arc_title': i['arc_title'],
        'series_chapter_number': i['absolute_file_number'],
        'arc_number': i['arc_number'],
        'pov': i['chapter_type'],
        'title': i['arc_title'] + ' - ' + i['chapter'],
        'chapter': i['chapter'].lower() # We'll use it later as a join key
    }}
    for idx, i in raw_dict.items()
    ]

# %%
with open('../data/twig_fmt_list.pkl','wb') as f:
    pickle.dump(twig_construct_list,f)
